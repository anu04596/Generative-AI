# %% [markdown]
# <a href="https://colab.research.google.com/github/anu04596/Generative-AI/blob/main/Practical_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist

# Load dataset
(x_train, _), (x_test, _) = mnist.load_data()

# Normalize and reshape
x_train = x_train.reshape(-1, 784) / 255.0
x_test = x_test.reshape(-1, 784) / 255.0

# Input layer
input_img = Input(shape=(784,))

# Encoder
encoded = Dense(64, activation='relu')(input_img)
encoded = Dense(32, activation='relu')(encoded)

# Decoder
decoded = Dense(64, activation='relu')(encoded)
decoded = Dense(784, activation='sigmoid')(decoded)

# Autoencoder model
autoencoder = Model(input_img, decoded)

# Compile model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Train model
autoencoder.fit(x_train, x_train,
                epochs=5,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.2557 - val_loss: 0.1725
# Epoch 2/5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.1543 - val_loss: 0.1391
# Epoch 3/5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1339 - val_loss: 0.1266
# Epoch 4/5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1235 - val_loss: 0.1183
# Epoch 5/5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1172 - val_loss: 0.1129
